# %%
import pandas as pd

# %% [markdown]
# ### Filling the null values of datasets before importing into database

# %% [markdown]
# #### CovidDeaths CSV

# %%
df = pd.read_csv("CovidDeaths.csv", parse_dates= True)
df.head(5)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.fillna("\\N", inplace= True)
df.head(5)
# Out:
# C:\Users\Sayed Ibrahim\AppData\Local\Temp\ipykernel_6456\4135933696.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\N' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("\\N", inplace= True)
#   iso_code continent     location       date total_cases new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020         1.0       1.0
# 1      AFG      Asia  Afghanistan  2/25/2020         1.0       0.0
# 2      AFG      Asia  Afghanistan  2/26/2020         1.0       0.0
# 3      AFG      Asia  Afghanistan  2/27/2020         1.0       0.0
# 4      AFG      Asia  Afghanistan  2/28/2020         1.0       0.0
#
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0                 \N           \N         \N                  \N  ...
# 1                 \N           \N         \N                  \N  ...
# ...

# %%
df.to_csv("covid_deaths.csv", index= False, encoding= 'utf-8')

# %% [markdown]
# #### CovidVaccinations CSV

# %%
df = pd.read_csv("CovidVaccinations.csv", parse_dates= True)
df.head(5)
# Out:
#   iso_code continent     location       date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  2/24/2020        NaN          NaN
# 1      AFG      Asia  Afghanistan  2/25/2020        NaN          NaN
# 2      AFG      Asia  Afghanistan  2/26/2020        NaN          NaN
# 3      AFG      Asia  Afghanistan  2/27/2020        NaN          NaN
# 4      AFG      Asia  Afghanistan  2/28/2020        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
df.fillna("\\N", inplace= True)
df.head(5)
# Out:
# C:\Users\Sayed Ibrahim\AppData\Local\Temp\ipykernel_22532\4135933696.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\N' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("\\N", inplace= True)
#   iso_code continent     location       date new_tests total_tests  \
# 0      AFG      Asia  Afghanistan  2/24/2020        \N          \N
# 1      AFG      Asia  Afghanistan  2/25/2020        \N          \N
# 2      AFG      Asia  Afghanistan  2/26/2020        \N          \N
# 3      AFG      Asia  Afghanistan  2/27/2020        \N          \N
# 4      AFG      Asia  Afghanistan  2/28/2020        \N          \N
#
#   total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# 0                       \N                     \N                 \N
# 1                       \N                     \N                 \N
# ...

# %%
df.to_csv("covid_vaccinations.csv", index= False, encoding= 'utf-8')
